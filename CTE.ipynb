# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('C:/Users/shary/Downloads/IRIS.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
count=df['species'].value_counts()
plt.bar(count.index,count.values)
plt.title('counts of specis')
plt.show()

# %%
plt.hist(df['petal_length'])
plt.title('petal lenght')
plt.xlabel('petal lenght')
plt.grid(True)
plt.show()

# %%
plt.scatter(df['sepal_length'],df['sepal_width'],c='green')
plt.title('sepal lenght and sepal width')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.show()

# %%
import pandas as pd
rain=pd.read_csv('C:/Users/shary/Downloads/district wise rainfall normal.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
